# %% [markdown]
# <div style="direction:rtl;text-align:center"><img src="https://dl.mohammadkh.ir/logo.png" alt="Mohammadkh.ir" style="width: 250px;"/></div>
# <h1><div style="direction:rtl;text-align:center">PreProcessing</div></h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv('../__data/jshare.csv')
plt.figure(figsize=(20, 12))
plt.plot(data['date'], data['data'])
plt.show()

# %% [markdown]
# ## stationary time series

# %%
adfuller(data['data'])
# Out:
# (2.7420165734574735,
#  1.0,
#  11,
#  72,
#  {'1%': -3.524624466842421,
#   '5%': -2.9026070739026064,
#   '10%': -2.5886785262345677},
#  82.63760283301102)

# %%
print('p value : ' , adfuller(data['data'])[1]) #--> p value < 0.05
# Out:
# p value :  1.0

# %% [markdown]
# ### log

# %%
data['data'] = np.log(data['data'])

plt.figure(figsize=(20, 12))
plt.plot(data['date'], data['data'])

print('p value : ' , adfuller(data['data'])[1])
# Out:
# p value :  0.8179273123168606

# %% [markdown]
# ### diff

# %%
sample = pd.Series([1, 1, 2, 3, 5, 8, 13, 21, 32, 55])
sample.diff(1)
# Out:
# 0     NaN
# 1     0.0
# 2     1.0
# 3     1.0
# 4     2.0
# 5     3.0
# 6     5.0
# 7     8.0
# 8    11.0
# 9    23.0
# dtype: float64

# %%
data['data'] = data['data'].diff()
data.dropna(axis=0,inplace=True)

plt.figure(figsize=(20, 12))
plt.plot(data['date'], data['data'])

print('p value : ' , adfuller(data['data'])[1])
# Out:
# p value :  0.00041497314044405543

# %% [markdown]
# <div class="alert alert-block alert-info">
# <div style="direction:rtl;text-align:left"><strong>PreProcessing</strong><br>MohammadReza <strong>Khajedaloi</strong><br><br>
# </div>
# <div style="direction:rtl;text-align:right">
# <a href="http://mohammadkh.ir/">WebSite</a> - <a href="https://github.com/khajedaloi/">GitHub</a> - <a href="https://www.linkedin.com/in/mohammad-kh/">Linkedin</a>
# </div>
# </div>
